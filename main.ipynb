# %%
# Use the csv module to load data from a CSV file into memory
import csv
import pandas as pd
import tui



def read_data(file_name):
  tui.started(f"Reading data from {file_name}")

  data = []

  with open(file_name, encoding="UTF-8") as csv_file:
    # Read the CSV file using the csv.reader() function.
    csv_reader = csv.reader(csv_file)
    headings = next(csv_reader)

    # Store the data in a list (do not convert it to a DataFrame).
    for row in csv_reader:
        data.append(row)

  # Load data from a CSV file into a Pandas DataFrame using the read_csv() function.
  # Use the file path or filename obtained from Task A (do not prompt the user again).
  df = pd.read_csv(file_name, encoding='utf-8', index_col='Patient_ID')

  tui.completed()
  return data, headings, df



def run():
  # Prompt the user to input the file path or filename for the CSV file.
  #file_name = input("Input CSV file path/name: ") # lung_cancer_data.csv
  file_name = "lung_cancer_data.csv" # TEST!
  data, headings, df = read_data(file_name)

  while True: # loop - returns back to the menu
    # Display the menu
    selected_option = tui.display_menu()

    if selected_option == '1':
      tui.A1(data) # test : 13117

    elif selected_option == '2':
      tui.A2(data) # test : Hispanic, Asian

    elif selected_option == '3':
      tui.A3(data) # test : Surgery

    elif selected_option == '4':
      tui.A4(data, headings)

    elif selected_option == '5':
      tui.B1(df)

    elif selected_option == '6':
      tui.B2(df)

    elif selected_option == '7':
      tui.B3(df)

    elif selected_option == '10':
      break

    else:
      tui.error("Invalid Selection!")



if __name__ == "__main__":
  run()

### CHANGE back all TEST! codes
# Out:
# -------------------------------------------------------------------------------------
# Operation started: Reading data from lung_cancer_data.csv...
#
#
# Operation completed.
# -------------------------------------------------------------------------------------
#
# Please select one of the following options:
# [1] Retrieve Demographic Information by patient ID
# [2] Retrieve Medical History Details by ethnicity
# [3] Retrieve Treatment Details
# [4] Retrieve the frequency of data occurrences by column
# [5] Identify Top 3 Treatments
# [6] Analyse Average White Blood Cell Counts
# [7] Smoking Packs Analysis by Tumor Location
# [10] Exit application
#
#     5
# List of ethnicities:
# Hispanic
# Caucasian
# African American
# Asian
# Other
# Enter an ethnicity: abc
#
# The top three treatments for the ethnicity other are
#
# | Treatment         |   Occurences |
# |-------------------|--------------|
# | Radiation Therapy |          207 |
# | Chemotherapy      |          204 |
# | Targeted Therapy  |          190 |
# Please select one of the following options:
# [1] Retrieve Demographic Information by patient ID
# [2] Retrieve Medical History Details by ethnicity
# [3] Retrieve Treatment Details
# [4] Retrieve the frequency of data occurrences by column
# [5] Identify Top 3 Treatments
# [6] Analyse Average White Blood Cell Counts
# [7] Smoking Packs Analysis by Tumor Location
# [10] Exit application
#
#     6
# List of ethnicities:
# Hispanic
# Caucasian
# African American
# Asian
# Other
# Enter an ethnicity: asian
#
# List of treatment types:
# Surgery
# Radiation Therapy
# Chemotherapy
# Targeted Therapy
# Enter a treatment type: SUrgery
#
# Average white blood cell counts for the ethnicity other and treatment type Surgery
#
# | Treatment   |   White_Blood_Cell_Count |
# |-------------|--------------------------|
# | Surgery     |                     6.71 |
# Please select one of the following options:
# [1] Retrieve Demographic Information by patient ID
# [2] Retrieve Medical History Details by ethnicity
# [3] Retrieve Treatment Details
# [4] Retrieve the frequency of data occurrences by column
# [5] Identify Top 3 Treatments
# [6] Analyse Average White Blood Cell Counts
# [7] Smoking Packs Analysis by Tumor Location
# [10] Exit application
#
#     7
# List of tumor locations:
# Lower Lobe
# Middle Lobe
# Upper Lobe
# Enter a tumor location: middle LOBE
#
# List of treatment types:
# Surgery
# Radiation Therapy
# Chemotherapy
# Targeted Therapy
# Enter a treatment type: chemotherapy
#
# Average smoking pack count for
#
# | Treatment    | Tumor_Location   |   Smoking_Pack_Years |
# |--------------|------------------|----------------------|
# | Chemotherapy | Middle Lobe      |                51.41 |
# Please select one of the following options:
# [1] Retrieve Demographic Information by patient ID
# [2] Retrieve Medical History Details by ethnicity
# [3] Retrieve Treatment Details
# [4] Retrieve the frequency of data occurrences by column
# [5] Identify Top 3 Treatments
# [6] Analyse Average White Blood Cell Counts
# [7] Smoking Packs Analysis by Tumor Location
# [10] Exit application
#
#     10
