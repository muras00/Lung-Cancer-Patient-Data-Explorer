# %%
# Use the csv module to load data from a CSV file into memory
import csv
import pandas as pd
import tui
import process



def read_data(file_name):
  tui.started(f"Reading data from {file_name}")

  data = []

  with open(file_name, encoding="UTF-8") as csv_file:
    # Read the CSV file using the csv.reader() function.
    csv_reader = csv.reader(csv_file)
    headings = next(csv_reader)

    # Store the data in a list (do not convert it to a DataFrame).
    for row in csv_reader:
        data.append(row)

  # Load data from a CSV file into a Pandas DataFrame using the read_csv() function.
  # Use the file path or filename obtained from Task A (do not prompt the user again).
  df = pd.read_csv(file_name, encoding='utf-8', index_col='Patient_ID')

  tui.completed()
  return data, headings, df



def run():
  # Prompt the user to input the file path or filename for the CSV file.
  file_name = input("Input CSV file path/name (lung_cancer_data.csv): ") # lung_cancer_data.csv
  data, headings, df = read_data(file_name)

  while True: # loop - returns back to the menu
    # Display the menu
    selected_option = tui.display_menu()

    if selected_option == '1':
      process.A1(data) # test : 13117

    elif selected_option == '2':
      process.A2(data) # test : Hispanic, Asian

    elif selected_option == '3':
      process.A3(data) # test : Surgery

    elif selected_option == '4':
      process.A4(data, headings)

    elif selected_option == '5':
      process.B1(df)

    elif selected_option == '6':
      process.B2(df)

    elif selected_option == '7':
      process.B3(df)

    elif selected_option == '8':
      process.B4(df)

    elif selected_option == '9':
      process.C1(df)
      input("Press Enter to continue...")

    elif selected_option == '10':
      process.C2(df)
      input("Press Enter to continue...")

    elif selected_option == '11':
      process.C3(df)
      input("Press Enter to continue...")

    elif selected_option == '12':
      process.C4(df)
      input("Press Enter to continue...")

    elif selected_option == '13':
      break

    else:
      tui.error("Invalid Selection!")
      input("Press Enter to continue...")



try:
    if __name__ == "__main__":
        run()
except FileNotFoundError:
    print("File does not exist")
# Out:
# Input CSV file path/name (lung_cancer_data.csv): lung_cancer_data.csv
# -------------------------------------------------------------------------------------
# Operation started: Reading data from lung_cancer_data.csv...
#
#
# Operation completed.
# -------------------------------------------------------------------------------------
#
# Please select one of the following options:
#
# -------------------------------------------------------------------------------------
# Get data using CSV module
# -------------------------------------------------------------------------------------
# [1] Retrieve Demographic Information by Patient ID
# [2] Retrieve Medical History Details by Ethnicity
# [3] Retrieve Patient Details by Treatment Type
# [4] Retrieve the Frequency of Data Occurrences by Column
#
# -------------------------------------------------------------------------------------
# Analyse data using Pandas module
# -------------------------------------------------------------------------------------
# [5] Identify Top Three Treatments by Ethnicity
# [6] Analyse Average White Blood Cell Counts by Ethnicity and Treatment Type
# [7] Smoking Packs Analysis by Tumor Location and Treatment Type
# [8] Survival Months Analysis by Cancer Stage and Treatment Type
#
# -------------------------------------------------------------------------------------
# Visualize data using Matplotlib module
# -------------------------------------------------------------------------------------
# [9] Proportion of Cancer Treatments by Ethnicity
# [10] Trend of Smoking Packs Across Cancer Stages and Ethnicities
# [11] Blood Pressure Comparison Across Treatment Types
# [12] Smoking History Percentages by Tumor Size and Cancer Stage
#
# -------------------------------------------------------------------------------------
#
# [13] Exit application
#
#     4
# Please select the column items to display:
# [1] Age
# [2] Gender
# [3] Smoking_History
# [4] Tumor_Location
# [5] Stage
# [6] Treatment
# [7] Survival_Months
# [8] Ethnicity
# [9] Insurance_Type
# [10] Family_History
# [11] Comorbidity_Diabetes
# [12] Comorbidity_Hypertension
# [13] Comorbidity_Heart_Disease
# [14] Comorbidity_Chronic_Lung_Disease
# [15] Comorbidity_Kidney_Disease
# [16] Comorbidity_Autoimmune_Disease
# [17] Comorbidity_Other
# [18] Performance_Status
# [19] Blood_Pressure_Systolic
# [20] Blood_Pressure_Diastolic
# [21] Blood_Pressure_Pulse
# 1
# Selected column: Age
#
# -------------------------------------------------------------------------------------
# Operation started: Retrieving the frequency of data occurrences for column Age...
#
# Age 30: 468
# Age 31: 474
# Age 32: 471
# Age 33: 473
# Age 34: 459
# Age 35: 451
# Age 36: 458
# Age 37: 486
# Age 38: 469
# Age 39: 477
# Age 40: 424
# Age 41: 458
# Age 42: 524
# Age 43: 475
# Age 44: 522
# Age 45: 472
# Age 46: 529
# Age 47: 493
# Age 48: 488
# Age 49: 451
# Age 50: 496
# Age 51: 480
# Age 52: 518
# Age 53: 482
# Age 54: 459
# Age 55: 522
# Age 56: 425
# Age 57: 493
# Age 58: 479
# Age 59: 445
# Age 60: 448
# Age 61: 469
# Age 62: 472
# Age 63: 465
# Age 64: 452
# Age 65: 467
# Age 66: 462
# Age 67: 463
# Age 68: 474
# Age 69: 465
# Age 70: 444
# Age 71: 466
# Age 72: 431
# Age 73: 484
# Age 74: 492
# Age 75: 433
# Age 76: 498
# Age 77: 514
# Age 78: 480
# Age 79: 458
#
#
# Operation completed.
# -------------------------------------------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 92
#      90 try:
#      91     if __name__ == "__main__":
# ---> 92         run()
#      93 except FileNotFoundError:
#      94     print("File does not exist")
#
# Cell In[2], line 51, in run()
#      48   process.A3(data) # test : Surgery
#      50 elif selected_option == '4':
# ---> 51   process.A4(data, headings)
#      53 elif selected_option == '5':
#      54   process.B1(df)
#
# File ~\Documents\_Solent\24_25_MSc_AI_DataScience\PFPS\assessment\submit\process.py:167, in A4(data, headings)
#     165 tui.display_A4(found, item_dict)
#     166 tui.completed()
# --> 167 input("Press Enter to continue...")
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1202, in Kernel.raw_input(self, prompt)
#    1200     msg = "raw_input was called, but this frontend does not support input requests."
#    1201     raise StdinNotImplementedError(msg)
# -> 1202 return self._input_request(
#    1203     str(prompt),
#    1204     self._parent_ident["shell"],
#    1205     self.get_parent("shell"),
#    1206     password=False,
#    1207 )
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1245, in Kernel._input_request(self, prompt, ident, parent, password)
#    1242 except KeyboardInterrupt:
#    1243     # re-raise KeyboardInterrupt, to truncate traceback
#    1244     msg = "Interrupted by user"
# -> 1245     raise KeyboardInterrupt(msg) from None
#    1246 except Exception:
#    1247     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
